# %% [markdown]
# # 01 基础：变量、类型、输入输出、条件与循环
# 目标：能写出读取输入、做简单计算、条件判断和循环的小脚本。

# %%
# 变量与类型
a = 3
b = 2.5
c = 'hello'
d = True
print(type(a), type(b), type(c), type(d))

# %%
# 练习：完成加法器。
# 从输入读取两个数字，输出它们的和。
# 提示：使用 input()，用 float() 转换。
# —— 在下方补全 ——
# x = float(input('第一个数: '))
# y = float(input('第二个数: '))
# print('和是:', x + y)

# %%
# 条件判断
age = 18
if age >= 18:
    print('成年')
else:
    print('未成年')

# %%
# 练习：成绩评级
# 输入 0-100 的分数，输出 A/B/C/D/E。
# 90+ A，80+ B，70+ C，60+ D，否则 E。
# —— 在下方补全 ——

# %%
# 循环
for i in range(5):
    print('i =', i)

# %%
# 练习：累加 1..n
# 输入 n，计算 1 到 n 的和。
# —— 在下方补全 ——

# %% [markdown]
# ## 自测
# 实现函数 `is_prime(n)` 返回是否为素数；并打印 1..100 中的所有素数。

# %%
# —— 在此实现 ——
def is_prime(n: int) -> bool:
    pass

# 打印 1..100 的素数
# for i in range(1, 101):
#     if is_prime(i):
#         print(i)
